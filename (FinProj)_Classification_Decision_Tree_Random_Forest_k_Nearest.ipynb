# %%
import pandas as pd
import numpy as np
file_path = 'Bullying_2018_clean.xlsx'
df = pd.read_excel(file_path)
df.head()
# Out:
#    record Bullied_on_school_property_in_past_12_months  \
# 0       2                                           No
# 1       3                                           No
# 2       4                                           No
# 3       5                                           No
# 4       6                                           No
#
#   Bullied_not_on_school_property_in_past_12_months  \
# 0                                               No
# 1                                               No
# 2                                               No
# 3                                               No
# 4                                               No
#
#   Cyber_bullied_in_past_12_months    Custom_Age     Sex Physically_attacked  \
# 0                              No  13 years old  Female             0 times
# 1                              No  14 years old    Male             0 times
# 2                              No  16 years old    Male             0 times
# 3                              No  13 years old  Female             0 times
# 4                              No  13 years old    Male             0 times
#
#   Physical_fighting Felt_lonely Close_friends Miss_school_no_permission  \
# 0           0 times       Never     3 or more                    0 days
# 1           0 times       Never     3 or more                    0 days
# 2      2 or 3 times       Never     3 or more                    0 days
# 3           0 times      Rarely     3 or more                    0 days
# 4            1 time       Never     3 or more                    0 days
#
#   Other_students_kind_and_helpful Parents_understand_problems  \
# 0                       Sometimes                      Always
# 1                       Sometimes                      Always
# 2                       Sometimes                         NaN
# 3                Most of the time            Most of the time
# 4                Most of the time                      Always
#
#   Most_of_the_time_or_always_felt_lonely  \
# 0                                     No
# 1                                     No
# 2                                     No
# 3                                     No
# 4                                     No
#
#   Missed_classes_or_school_without_permission Were_underweight  \
# 0                                          No              NaN
# 1                                          No               No
# 2                                          No               No
# 3                                          No              NaN
# 4                                          No               No
#
#   Were_overweight Were_obese
# 0             NaN        NaN
# 1              No         No
# 2              No         No
# 3             NaN        NaN
# 4              No         No

# %%
#Let us first try to get the accuracy score of the data without it being cleaned
from sklearn.preprocessing import LabelEncoder

# encode categorical variables
le = LabelEncoder()
df['Bullied_on_school_property_in_past_12_months'] = le.fit_transform(df['Bullied_on_school_property_in_past_12_months'])
df['Bullied_not_on_school_property_in_past_12_months'] = le.fit_transform(df['Bullied_not_on_school_property_in_past_12_months'])
df['Cyber_bullied_in_past_12_months'] = le.fit_transform(df['Cyber_bullied_in_past_12_months'])
df['Sex'] = le.fit_transform(df['Sex'])
df['Felt_lonely'] = le.fit_transform(df['Felt_lonely'])
df['Miss_school_no_permission'] = le.fit_transform(df['Miss_school_no_permission'])
df['Other_students_kind_and_helpful'] = le.fit_transform(df['Other_students_kind_and_helpful'])
df['Parents_understand_problems'] = le.fit_transform(df['Parents_understand_problems'])
df['Most_of_the_time_or_always_felt_lonely'] = le.fit_transform(df['Most_of_the_time_or_always_felt_lonely'])
df['Missed_classes_or_school_without_permission'] = le.fit_transform(df['Missed_classes_or_school_without_permission'])
df['Custom_Age'] = le.fit_transform(df['Custom_Age'])
df['Physically_attacked'] = le.fit_transform(df['Physically_attacked'])
df['Physical_fighting'] = le.fit_transform(df['Physical_fighting'])
df['Close_friends'] = le.fit_transform(df['Close_friends'])
df['Were_obese'] = le.fit_transform(df['Were_obese'])
df['Were_overweight'] = le.fit_transform(df['Were_overweight'])
df['Were_underweight'] = le.fit_transform(df['Were_underweight'])
from sklearn.model_selection import train_test_split

# split data into training and testing sets
X = df.drop(['record', 'Bullied_on_school_property_in_past_12_months'], axis=1)
y = df['Bullied_on_school_property_in_past_12_months']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
from sklearn.tree import DecisionTreeClassifier

# train decision tree classifier
clf = DecisionTreeClassifier(random_state=42)
clf.fit(X_train, y_train)

from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, precision_score, f1_score

#predict dependent data
y_pred = clf.predict(X_test)
print("Using Decision Tree")
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
precision = precision_score(y_test, y_pred)
print("Precision: %.2f%%" % (precision * 100.0))
f1 = f1_score(y_test, y_pred)
print("f1 score: %.2f%%" % (f1 * 100.0))
# Out:
# Using Decision Tree
# [[10569  1820]
#  [ 2209  1221]]
#               precision    recall  f1-score   support
#
#            0       0.83      0.85      0.84     12389
#            1       0.40      0.36      0.38      3430
#
#     accuracy                           0.75     15819
#    macro avg       0.61      0.60      0.61     15819
# weighted avg       0.73      0.75      0.74     15819
#
# Accuracy: 74.53%
# Precision: 40.15%
# f1 score: 37.74%

# %%
# Let us then find a way to improve the overall accuracy by removing null values to see their difference
# Replace all whitespace and non-visible characters with NaN values
df.replace(r'^\s*$', np.nan, regex=True, inplace=True)
from ipykernel import kernelapp as app
import matplotlib.pyplot as plt

# Calculate the percentage of missing values in each column
missing_perc = (df.isnull().sum() / len(df)) * 100

# Sort the columns by percentage of missing values in descending order
missing_perc_sorted = missing_perc.sort_values(ascending=False)

# Calculate the cumulative percentage of missing values
cumulative_perc = missing_perc_sorted.cumsum()

# Create a Pareto chart
fig, ax1 = plt.subplots(figsize=(10, 6))
ax1.bar(missing_perc_sorted.index, missing_perc_sorted.values, color='tab:blue')
ax1.set_xlabel('Columns')
ax1.set_ylabel('Percentage of missing values', color='tab:blue')
ax1.set_xticklabels(missing_perc_sorted.index, rotation=90)

# Add a secondary y-axis for the cumulative percentage
ax2 = ax1.twinx()
ax2.plot(missing_perc_sorted.index, cumulative_perc.values, color='tab:red', marker='o')
ax2.set_ylabel('Cumulative percentage', color='tab:red')


# Rotate the x-axis labels for better visibility
plt.xticks(rotation=90)

# Show the plot
plt.show()
# Drop columns with a high proportion of missing values
df.drop(['Were_underweight', 'Were_overweight', 'Were_obese'], axis=1, inplace=True)

#dropping na values
df=df.dropna()
df.head()
# Out:
# <ipython-input-11-2291fc2f720c>:21: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(missing_perc_sorted.index, rotation=90)
#    record Bullied_on_school_property_in_past_12_months  \
# 0       2                                           No
# 1       3                                           No
# 3       5                                           No
# 4       6                                           No
# 5       7                                           No
#
#   Bullied_not_on_school_property_in_past_12_months  \
# 0                                               No
# 1                                               No
# 3                                               No
# 4                                               No
# 5                                               No
#
#   Cyber_bullied_in_past_12_months    Custom_Age     Sex Physically_attacked  \
# 0                              No  13 years old  Female             0 times
# 1                              No  14 years old    Male             0 times
# 3                              No  13 years old  Female             0 times
# 4                              No  13 years old    Male             0 times
# 5                              No  14 years old  Female              1 time
#
#   Physical_fighting Felt_lonely Close_friends Miss_school_no_permission  \
# 0           0 times       Never     3 or more                    0 days
# 1           0 times       Never     3 or more                    0 days
# 3           0 times      Rarely     3 or more                    0 days
# 4            1 time       Never     3 or more                    0 days
# 5           0 times   Sometimes     3 or more                    0 days
#
#   Other_students_kind_and_helpful Parents_understand_problems  \
# 0                       Sometimes                      Always
# 1                       Sometimes                      Always
# 3                Most of the time            Most of the time
# 4                Most of the time                      Always
# 5                Most of the time                      Always
#
#   Most_of_the_time_or_always_felt_lonely  \
# 0                                     No
# 1                                     No
# 3                                     No
# 4                                     No
# 5                                     No
#
#   Missed_classes_or_school_without_permission
# 0                                          No
# 1                                          No
# 3                                          No
# 4                                          No
# 5                                          No

# %%
non_null_counts = df.count()# Get the count of non-null values for each column

# Check if all columns have the same count of non-null values
if non_null_counts.nunique() == 1:
    print("Total null values:", df.isnull().sum().sum())
else:
    print("Columns have different counts of non-null values.")
# Out:
# Total null values: 0

# %%
from sklearn.preprocessing import LabelEncoder

# encode categorical variables
le = LabelEncoder()
df['Bullied_on_school_property_in_past_12_months'] = le.fit_transform(df['Bullied_on_school_property_in_past_12_months'])
df['Bullied_not_on_school_property_in_past_12_months'] = le.fit_transform(df['Bullied_not_on_school_property_in_past_12_months'])
df['Cyber_bullied_in_past_12_months'] = le.fit_transform(df['Cyber_bullied_in_past_12_months'])
df['Sex'] = le.fit_transform(df['Sex'])
df['Felt_lonely'] = le.fit_transform(df['Felt_lonely'])
df['Miss_school_no_permission'] = le.fit_transform(df['Miss_school_no_permission'])
df['Other_students_kind_and_helpful'] = le.fit_transform(df['Other_students_kind_and_helpful'])
df['Parents_understand_problems'] = le.fit_transform(df['Parents_understand_problems'])
df['Most_of_the_time_or_always_felt_lonely'] = le.fit_transform(df['Most_of_the_time_or_always_felt_lonely'])
df['Missed_classes_or_school_without_permission'] = le.fit_transform(df['Missed_classes_or_school_without_permission'])
df['Custom_Age'] = le.fit_transform(df['Custom_Age'])
df['Physically_attacked'] = le.fit_transform(df['Physically_attacked'])
df['Physical_fighting'] = le.fit_transform(df['Physical_fighting'])
df['Close_friends'] = le.fit_transform(df['Close_friends'])

# %%
from sklearn.model_selection import train_test_split

# split data into training and testing sets
X = df.drop(['record', 'Bullied_on_school_property_in_past_12_months'], axis=1)
y = df['Bullied_on_school_property_in_past_12_months']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier

# train decision tree classifier
clf = DecisionTreeClassifier(random_state=42)
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
#predict dependent data
y_pred = clf.predict(X_test)

# %%
# Create a DataFrame with actual records, actual labels, and predicted labels
result_df_dt_ = pd.DataFrame({
    'Record': df.loc[X_test.index, 'record'],
    'Actual_Labels': y_test,
    'Predicted_Labels_DecisionTree': y_pred,
})

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, precision_score, f1_score

print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))

# Save the concatenated DataFrame to a CSV file
print("Using Decision Tree")
result_df_dt_.to_csv('predictionBIDT.csv', index=False)
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
precision = precision_score(y_test, y_pred)
print("Precision: %.2f%%" % (precision * 100.0))
f1 = f1_score(y_test, y_pred)
print("f1 score: %.2f%%" % (f1 * 100.0))
# Out:
# [[10563  1580]
#  [ 2092  1098]]
#               precision    recall  f1-score   support
#
#            0       0.83      0.87      0.85     12143
#            1       0.41      0.34      0.37      3190
#
#     accuracy                           0.76     15333
#    macro avg       0.62      0.61      0.61     15333
# weighted avg       0.75      0.76      0.75     15333
#
# Using Decision Tree
# Accuracy: 76.05%
# Precision: 41.00%
# f1 score: 37.42%

# %%
from sklearn.ensemble import RandomForestClassifier
# Create a Random Forest classifier
rf_classifier = RandomForestClassifier(n_estimators=100, random_state=42)

# Train the classifier on the training data
rf_classifier.fit(X_train, y_train)

# Make predictions on the testing data
y_pred = rf_classifier.predict(X_test)

# Create a DataFrame with actual records, actual labels, and predicted labels
result_df_rt_ = pd.DataFrame({
    'Record': df.loc[X_test.index, 'record'],  # Assuming 'record' is a DataFrame with the 'record' column
    'Actual_Labels': y_test,
    'Predicted_Labels_RandomForest': y_pred,
})

# Evaluate and
# Save the results to a CSV file
print("Using Random Forest")
result_df_rt_.to_csv('predictionBIRF.csv', index=False)
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
precision = precision_score(y_test, y_pred)
print("Precision: %.2f%%" % (precision * 100.0))
f1 = f1_score(y_test, y_pred)
print("f1 score: %.2f%%" % (f1 * 100.0))
# Out:
# Accuracy: 0.80
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.84      0.92      0.88     12143
#            1       0.51      0.34      0.41      3190
#
#     accuracy                           0.80     15333
#    macro avg       0.68      0.63      0.64     15333
# weighted avg       0.77      0.80      0.78     15333
#
# Accuracy: 79.59%
# Precision: 51.47%
# f1 score: 40.64%

# %%
# Use K-Nearest Neighbour (KNN) algorithm with defined parameter of the number of neighbour (n)
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors=3)
# KNN algorithm model fit
classifier.fit(X_train, y_train)
# KNN model classifier prediction
y_pred = classifier.predict(X_test)

# %%
# Create a DataFrame with actual records, actual labels, and predicted labels
result_df_knn_ = pd.DataFrame({
    'Record': df.loc[X_test.index, 'record'],  # Assuming 'record' is a DataFrame with the 'record' column
    'Actual_Labels': y_test,
    'Predicted_Labels_KNN': y_pred,
})

# %%
# KNN model evaluation using confusion matrix and precision, recall, f1, support scores
print("Using KNN")
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, precision_score, f1_score
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
result_df_knn_.to_csv('predictionknnBI.csv', index=False)
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
precision = precision_score(y_test, y_pred)
print("Precision: %.2f%%" % (precision * 100.0))
f1 = f1_score(y_test, y_pred)
print("f1 score: %.2f%%" % (f1 * 100.0))
# Out:
# [[11086  1057]
#  [ 2264   926]]
#               precision    recall  f1-score   support
#
#            0       0.83      0.91      0.87     12143
#            1       0.47      0.29      0.36      3190
#
#     accuracy                           0.78     15333
#    macro avg       0.65      0.60      0.61     15333
# weighted avg       0.75      0.78      0.76     15333
#
# Accuracy: 78.34%
# Precision: 46.70%
# f1 score: 35.80%

# %%
#SUBDIVIDER Below is bullying Outside being split as test data

# %%
# split data into training and testing sets
X = df.drop(['record', 'Bullied_not_on_school_property_in_past_12_months'], axis=1)
y = df['Bullied_not_on_school_property_in_past_12_months']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# train decision tree classifier
clf = DecisionTreeClassifier(random_state=42)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)

# %%
# Create a DataFrame with actual records, actual labels, and predicted labels
result_df_dectree_ = pd.DataFrame({
    'Record': df.loc[X_test.index, 'record'],  # Assuming 'record' is a DataFrame with the 'record' column
    'Actual_Labels': y_test,
    'Predicted_Labels_DecisionTree': y_pred,
})

# %%
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))

# Save the results to a CSV file
result_df_dectree_.to_csv('predictionBODT.csv', index=False)

accuracy = accuracy_score(y_test, y_pred)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
precision = precision_score(y_test, y_pred)
print("Precision: %.2f%%" % (precision * 100.0))
f1 = f1_score(y_test, y_pred)
print("f1 score: %.2f%%" % (f1 * 100.0))
# Out:
# [[10573  1522]
#  [ 2031  1207]]
#               precision    recall  f1-score   support
#
#            0       0.84      0.87      0.86     12095
#            1       0.44      0.37      0.40      3238
#
#     accuracy                           0.77     15333
#    macro avg       0.64      0.62      0.63     15333
# weighted avg       0.76      0.77      0.76     15333
#
# Accuracy: 76.83%
# Precision: 44.23%
# f1 score: 40.46%

# %%
from sklearn.ensemble import RandomForestClassifier
# Create a Random Forest classifier
rf_classifier = RandomForestClassifier(n_estimators=100, random_state=42)

# Train the classifier on the training data
rf_classifier.fit(X_train, y_train)

# Make predictions on the testing data
y_pred = rf_classifier.predict(X_test)
# Create a DataFrame with actual records, actual labels, and predicted labels
result_df_rt_ = pd.DataFrame({
    'Record': df.loc[X_test.index, 'record'],  # Assuming 'record' is a DataFrame with the 'record' column
    'Actual_Labels': y_test,
    'Predicted_Labels_RandomForest': y_pred,
})
# Save the results to a CSV file
result_df_rt_.to_csv('predictionBORF.csv', index=False)

# Evaluate the classifier
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.2f}")

print("\nClassification Report:")
print(classification_report(y_test, y_pred))
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
precision = precision_score(y_test, y_pred)
print("Precision: %.2f%%" % (precision * 100.0))
f1 = f1_score(y_test, y_pred)
print("f1 score: %.2f%%" % (f1 * 100.0))
# Out:
# Accuracy: 0.80
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.84      0.91      0.88     12095
#            1       0.53      0.37      0.44      3238
#
#     accuracy                           0.80     15333
#    macro avg       0.69      0.64      0.66     15333
# weighted avg       0.78      0.80      0.78     15333
#
# Accuracy: 79.80%
# Precision: 53.09%
# f1 score: 43.73%

# %%
# Use K-Nearest Neighbour (KNN) algorithm with defined parameter of the number of neighbour (n)
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors=3)
# KNN algorithm model fit
classifier.fit(X_train, y_train)
# KNN model classifier prediction
y_pred = classifier.predict(X_test)

# %%
# Create a DataFrame with actual records, actual labels, and predicted labels
result_df_knn_ = pd.DataFrame({
    'Record': df.loc[X_test.index, 'record'],  # Assuming 'record' is a DataFrame with the 'record' column
    'Actual_Labels': y_test,
    'Predicted_Labels_KNN': y_pred,
})

# %%
# KNN model evaluation using confusion matrix and precision, recall, f1, support scores
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
result_df_knn_.to_csv('predictionknnBO.csv', index=False)

accuracy = accuracy_score(y_test, y_pred)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
precision = precision_score(y_test, y_pred)
print("Precision: %.2f%%" % (precision * 100.0))
f1 = f1_score(y_test, y_pred)
print("f1 score: %.2f%%" % (f1 * 100.0))
# Out:
# [[11023  1072]
#  [ 2212  1026]]
#               precision    recall  f1-score   support
#
#            0       0.83      0.91      0.87     12095
#            1       0.49      0.32      0.38      3238
#
#     accuracy                           0.79     15333
#    macro avg       0.66      0.61      0.63     15333
# weighted avg       0.76      0.79      0.77     15333
#
# Accuracy: 78.58%
# Precision: 48.90%
# f1 score: 38.46%
